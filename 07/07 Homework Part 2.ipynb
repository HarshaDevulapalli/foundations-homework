# %% [markdown]
# # BILLIONAIRES

# %% [markdown]
# Let us first import the database.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel("richpeople.xlsx")

# %%
rich = df[df['year'] == 2014] #Getting only the latest list.

# %%
rich.head(5)
# Out:
#    year                          name  rank           citizenship countrycode  \
# 1  2014          A. Jerrold Perenchio   663         United States         USA
# 5  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 6  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 8  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 9  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 1                2.6  self-made            executive   male  83.0   ...
# 5                2.5  inherited            inherited   male   NaN   ...
# 6                4.8  inherited            inherited   male   NaN   ...
# 8                2.4  self-made    self-made finance   male   NaN   ...
# 9                1.2  self-made  founder non-finance   male  54.0   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 1  former chairman and CEO       1955.0          NaN
# 5                 relation       1930.0          NaN
# 6                 relation       1960.0          NaN
# 8                  founder       1957.0          NaN
# 9                  founder       1988.0          NaN
#
#               sourceofwealth                                           notes  \
# 1      television, Univision  represented Marlon Brando and Elizabeth Taylor
# 5  auto dealers, investments    company split between him and cousin in 2000
# 6                diversified                           inherited from father
# 8                    banking                                             NaN
# 9       sugar, flour, cement                                             NaN
#
#    notes2                                           source  \
# 1     NaN     http://en.wikipedia.org/wiki/Jerry_Perenchio
# 5     NaN    http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 6     NaN    http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 8     NaN       http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 9     NaN  http://www.forbes.com/profile/abdulsamad-rabiu/
#
#                                             source_2  \
# 1  http://www.forbes.com/profile/a-jerrold-perenc...
# 5  http://www.al-futtaim.ae/content/groupProfile.asp
# 6      http://www.alghurair.com/about-us/our-history
# 8  http://www.alrajhibank.com.sa/ar/investor-rela...
# 9  http://www.bloomberg.com/research/stocks/priva...
#
#                                             source_3 source_4
# 1  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 5                                                NaN      NaN
# 6                                                NaN      NaN
# 8  http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 9                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
rich.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %% [markdown]
# What country are most billionaires from? For the top ones, how many billionaires per billion people?

# %%
numberofbillionaires=rich['countrycode'].value_counts() #Clearly, Americans lead. 
numberofbillionaires.head(10)
# Out:
# USA    499
# CHN    152
# RUS    111
# DEU     85
# BRA     65
# IND     56
# GBR     47
# HKG     45
# FRA     43
# ITA     35
# Name: countrycode, dtype: int64

# %%
numberofbillionairesperbillionpeople=numberofbillionaires/1000000000
numberofbillionairesperbillionpeople.head(6)
# Out:
# USA    4.990000e-07
# CHN    1.520000e-07
# RUS    1.110000e-07
# DEU    8.500000e-08
# BRA    6.500000e-08
# IND    5.600000e-08
# Name: countrycode, dtype: float64

# %% [markdown]
# Who are the top 10 richest billionaires?

# %%
sortedrich=rich.sort_values(by='networthusbillion',ascending=False)
sortedrich.head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
# 1128  2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# 124                64.0  self-made       founder non-finance    male  77.0
# 2491               58.2  self-made       founder non-finance    male  83.0
# 1377               48.0  self-made       founder non-finance    male  69.0
# 509                40.0  inherited                 inherited    male  73.0
# 381                40.0  inherited                 inherited    male  78.0
# 2185               38.0  self-made         self-made finance    male  80.0
# 429                36.7  inherited                 inherited  female  59.0
# 1128               34.7  inherited                 inherited    male  66.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 284    ...                  founder       1975.0          NaN
# 348    ...                  founder       1990.0          NaN
# 124    ...                  founder       1975.0          NaN
# 2491   ...                  founder       1839.0          NaN
# 1377   ...                  founder       1977.0          NaN
# 509    ...                 relation       1940.0          NaN
# 381    ...                 relation       1940.0          NaN
# 2185   ...                  founder       1952.0          NaN
# 429    ...                 relation       1962.0          NaN
# 1128   ...                 relation       1962.0          NaN
#
#           sourceofwealth                  notes  notes2  \
# 284            Microsoft                    NaN     NaN
# 348              telecom                    NaN     NaN
# 124               retail                    NaN     NaN
# 2491  Berkshire Hathaway                    NaN     NaN
# 1377              Oracle                    NaN     NaN
# 509          diversified  inherited from father     NaN
# 381          diversified  inherited from father     NaN
# 2185             casinos                    NaN     NaN
# 429             Wal-Mart                  widow     NaN
# 1128            Wal-Mart  inherited from father     NaN
#
#                                                  source  \
# 284           http://www.forbes.com/profile/bill-gates/
# 348   http://www.ozy.com/provocateurs/carlos-slims-w...
# 124       http://www.forbes.com/profile/amancio-ortega/
# 2491  http://www.forbes.com/lists/2009/10/billionair...
# 1377       http://www.forbes.com/profile/larry-ellison/
# 509   http://www.kochind.com/About_Koch/History_Time...
# 381   http://www.kochind.com/About_Koch/History_Time...
# 2185     http://www.forbes.com/profile/sheldon-adelson/
# 429       http://www.forbes.com/profile/christy-walton/
# 1128          http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 284                                                 NaN      NaN      NaN
# 348                                                 NaN      NaN      NaN
# 124                                                 NaN      NaN      NaN
# 2491  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 1377  http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 509                                                 NaN      NaN      NaN
# 381                                                 NaN      NaN      NaN
# 2185  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 429                                                 NaN      NaN      NaN
# 1128                                                NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# Who is the poorest billionaire? Who are the top 10 poorest billionaires?

# %%
sortedpoor=rich.sort_values(by='networthusbillion')
sortedpoor.head(10)
# Out:
#       year               name  rank    citizenship countrycode  \
# 234   2014        B.R. Shetty  1565          India         IND
# 2092  2014       Rostam Azizi  1565       Tanzania         TZA
# 2401  2014         Tory Burch  1565  United States         USA
# 734   2014         Fred Chang  1565  United States         USA
# 171   2014     Angela Bennett  1565      Australia         AUS
# 748   2014            Fu Kwan  1565          China         CHN
# 2107  2014     Ryan Kavanaugh  1565  United States         USA
# 1783  2014  O. Francis Biondi  1565  United States         USA
# 1371  2014       Lam Fong Ngo  1565          Macau         MAC
# 702   2014      Feng Hailiang  1565          China         CHN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 234                 1.0  self-made  founder non-finance    male  72.0
# 2092                1.0  self-made            executive    male  49.0
# 2401                1.0  self-made  founder non-finance  female  47.0
# 734                 1.0  self-made  founder non-finance    male  57.0
# 171                 1.0  inherited            inherited  female  69.0
# 748                 1.0  self-made    self-made finance    male  56.0
# 2107                1.0  self-made  founder non-finance    male  39.0
# 1783                1.0  self-made    self-made finance    male  49.0
# 1371                1.0  self-made    self-made finance  female   NaN
# 702                 1.0  self-made  founder non-finance    male  53.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 234    ...                  founder       1975.0          NaN
# 2092   ...                 investor       1999.0          NaN
# 2401   ...                  founder       2004.0          NaN
# 734    ...                  founder       2001.0          NaN
# 171    ...                 relation       1955.0          NaN
# 748    ...                 chairman       1990.0          NaN
# 2107   ...                  founder       2004.0          NaN
# 1783   ...                  founder       1995.0          NaN
# 1371   ...            Vice Chairman       1997.0          NaN
# 702    ...                  founder       1989.0          NaN
#
#                        sourceofwealth                  notes  \
# 234                        healthcare                    NaN
# 2092             telecom, investments                    NaN
# 2401                          fashion                    NaN
# 734                  online retailing                    NaN
# 171                            mining  inherited from father
# 748                       diversified                    NaN
# 2107                           Movies                    NaN
# 1783                       hedge fund                    NaN
# 1371                          casinos                    NaN
# 702   copper processing & real estate                    NaN
#
#                            notes2  \
# 234                           NaN
# 2092                          NaN
# 2401                          NaN
# 734                           NaN
# 171   shared fortune with brother
# 748                           NaN
# 2107                          NaN
# 1783                          NaN
# 1371                          NaN
# 702                           NaN
#
#                                                  source  \
# 234           http://en.wikipedia.org/wiki/B._R._Shetty
# 2092        http://www.forbes.com/profile/rostam-azizi/
# 2401  http://en.wikipedia.org/wiki/J._Christopher_Burch
# 734                 http://en.wikipedia.org/wiki/Newegg
# 171       http://www.forbes.com/profile/angela-bennett/
# 748              http://www.forbes.com/profile/fu-kwan/
# 2107        http://en.wikipedia.org/wiki/Ryan_Kavanaugh
# 1783    http://www.forbes.com/profile/o-francis-biondi/
# 1371        http://www.forbes.com/profile/david-chow-1/
# 702        http://www.forbes.com/profile/feng-hailiang/
#
#                                                source_2  \
# 234              http://www.nmchealth.com/dr-br-shetty/
# 2092      http://en.wikipedia.org/wiki/Vodacom_Tanzania
# 2401  http://www.vanityfair.com/news/2007/02/tory-bu...
# 734           http://www.newegg.com/Info/FactSheet.aspx
# 171                                                 NaN
# 748        http://www.macrolink.com.cn/en/AboutBig.aspx
# 2107      http://en.wikipedia.org/wiki/Relativity_Media
# 1783  http://www.forbes.com/sites/nathanvardi/2014/0...
# 1371  http://www.macaulegend.com/html/about_mileston...
# 702            http://www.hailiang.com/en/about_int.php
#
#                                                source_3 source_4
# 234                                                 NaN      NaN
# 2092  http://www.thecitizen.co.tz/News/Rostam--Dewji...      NaN
# 2401                                                NaN      NaN
# 734   http://www.forbes.com/sites/andreanavarro/2014...      NaN
# 171                                                 NaN      NaN
# 748                                                 NaN      NaN
# 2107  http://www.vanityfair.com/news/2010/03/kavanau...      NaN
# 1783                                                NaN      NaN
# 1371  Macau Legend to roll the dice on HK IPO; But l...      NaN
# 702                                                 NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# 'What is relationship to company'? And what are the most common relationships?

# %%
rich['relationshiptocompany'].head(5)
# Out:
# 1    former chairman and CEO
# 5                   relation
# 6                   relation
# 8                    founder
# 9                    founder
# Name: relationshiptocompany, dtype: object

# %% [markdown]
# It is how the millionaire is related to the company in the industry from which they made the billions.

# %%
relations=rich['relationshiptocompany'].value_counts()
relations.head(10) #The problem with the dataset is a little apparent now. 
#CEO and ceo are seen differently. Chairman AND Ceo is one category, either of those are separate categories.
#One can replace ceo with CEO and see how things change.
# Out:
# founder                                 818
# relation                                515
# owner                                    79
# chairman                                 64
# investor                                 30
# Chairman and Chief Executive Officer     15
# president                                 8
# Chairman                                  8
# CEO                                       8
# ceo                                       8
# Name: relationshiptocompany, dtype: int64

# %%
rich1=rich.replace(['ceo'],['CEO'])

# %%
relations=rich1['relationshiptocompany'].value_counts()
relations.head(10) #The newer version of rich has CEOs merged into one list. So CEO is sixth most common position after investor.
# Out:
# founder                                 818
# relation                                515
# owner                                    79
# chairman                                 64
# investor                                 30
# CEO                                      16
# Chairman and Chief Executive Officer     15
# president                                 8
# Chairman                                  8
# founder and chairman                      6
# Name: relationshiptocompany, dtype: int64

# %% [markdown]
# Most common source of wealth? Male vs. female?

# %%
source=rich1['sourceofwealth'].value_counts()
source.head(10) #REAL ESTATE IS WHERE THE MONEY IS, GUYS! "Diversified", HAHA!
maleb=rich1[rich1['gender']=='male']
maleb['sourceofwealth'].value_counts()
# Out:
# real estate                      100
# retail                            60
# diversified                       60
# investments                       58
# pharmaceuticals                   40
# hedge funds                       34
# banking                           30
# construction                      27
# media                             18
# software                          18
# private equity                    16
# finance                           15
# consumer goods                    14
# manufacturing                     12
# steel                             11
# telecom                           10
# electronics                        9
# mining                             9
# education                          8
# oil                                8
# money management                   8
# chemicals                          8
# insurance                          8
# Facebook                           8
# casinos                            7
# hotels                             7
# beer                               7
# beverages                          7
# shipping                           7
# auto parts                         6
#                                 ...
# auto import and dealerships        1
# Inheritance, oil, real estate      1
# record label                       1
# movie making                       1
# hedge Fund                         1
# insurance & real estate            1
# insurance, real estate             1
# flooring                           1
# Netscape, investments              1
# Dell                               1
# circus, live entertainment         1
# drugstore chain                    1
# port, gas                          1
# sewage treatment                   1
# Kyobo Life Insurance               1
# banking, shipping                  1
# FedEx                              1
# Celltrion                          1
# inherited, mining                  1
# DirecTV                            1
# tobacco, banking                   1
# employment agency                  1
# animation                          1
# cement, sugar, flour               1
# Wal-Mart, logistics                1
# Star Wars                          1
# real estate, shipping              1
# cars                               1
# textiles, apparel                  1
# palm oil, real estate              1
# Name: sourceofwealth, dtype: int64

# %%
femaleb=rich1[rich1['gender']=='female']
femaleb['sourceofwealth'].value_counts()
# Out:
# diversified                          9
# real estate                          7
# media                                6
# consumer goods                       5
# construction                         5
# hotels, investments                  5
# chemicals                            4
# casinos                              4
# Wal-Mart                             4
# cleaning products                    4
# packaging                            3
# Samsung                              3
# commodities                          3
# pipelines                            3
# banking                              3
# retail                               3
# mining                               3
# Cargill Inc.                         2
# paper                                2
# Campbell Soup                        2
# inherited, cosmetics                 2
# coffee                               2
# medical equipment                    2
# steel                                2
# bank, media                          2
# financial services                   2
# insurance                            2
# pharmaceuticals                      2
# hotels, restaurants                  2
# publishing                           2
#                                     ..
# beer                                 1
# Prada                                1
# self storage                         1
# forestry, mining                     1
# Facebook                             1
# appliance retailer                   1
# retailer                             1
# Inherited                            1
# television                           1
# Computer Associates                  1
# Dolby Laboratories                   1
# construction, investments            1
# San Francisco 49ers                  1
# hospitals, health care               1
# cement firm inheritance              1
# Apple, Disney                        1
# health IT                            1
# H&M                                  1
# Gap                                  1
# toll roads                           1
# gas, petrochemicals                  1
# Carnival Cruises                     1
# oil & gas, investments               1
# art collection, Swatch               1
# fashion                              1
# mining, banking                      1
# roofing                              1
# Roche Holding                        1
# medical devices                      1
# book distribution, transportation    1
# Name: sourceofwealth, dtype: int64

# %%
rich1['gender'].value_counts() #Inherent Patriarchy perhaps
# Out:
# male      1473
# female     180
# Name: gender, dtype: int64

# %% [markdown]
# Given the richest person in a country, what % of the GDP is their wealth?

# %%
gdp_csv=pd.read_csv('http://data.okfn.org/data/core/gdp/r/gdp.csv')
gdp_2014 = gdp_csv[gdp_csv['Year'] == 2014]
gdp_2014.tail()
gdp_2014=gdp_2014.rename(columns={'Country Code': 'countrycode'})
gdp_2014.tail()
rich2=pd.merge(rich1, gdp_2014, on='countrycode', how='outer')
rich2['percentageofcountrygdptheirwealthis']=(rich2['networthusbillion'])/(rich2['Value'])
rich2['percentageofcountrygdptheirwealthis'].head()
# Out:
# 0    1.492623e-13
# 1    9.931684e-13
# 2    6.314943e-14
# 3    8.037201e-14
# 4    1.148172e-13
# Name: percentageofcountrygdptheirwealthis, dtype: float64

# %% [markdown]
# What's the average wealth of a billionaire? Male? Female?

# %%
df['networthusbillion'].describe()
# Out:
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
maleb['networthusbillion'].describe()
# Out:
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
femaleb['networthusbillion'].describe()
# Out:
# count    180.000000
# mean       3.920556
# std        5.312604
# min        1.000000
# 25%        1.400000
# 50%        2.300000
# 75%        3.700000
# max       36.700000
# Name: networthusbillion, dtype: float64

# %% [markdown]
# Add up the wealth of all of the billionaires in a given country (or a few countries) and then compare it to the GDP of the country, or other billionaires, so like pit the US vs India

# %%
americanbillionaires=rich2[rich2['countrycode']=='USA']
indianbillionaires=rich2[rich2['countrycode']=='IND']
wealthofamerica=americanbillionaires['networthusbillion'].sum()
wealthofamerica
# Out:
# 2322.3999999999996

# %%
wealthofindia=indianbillionaires['networthusbillion'].sum()
wealthofindia
# Out:
# 191.90000000000001

# %% [markdown]
# What are the most common industries for billionaires to come from? What's the total amount of billionaire money from each industry?

# %%
rich2['industry'].value_counts()
# Out:
# Consumer                           291
# Real Estate                        190
# Retail, Restaurant                 174
# Diversified financial              132
# Technology-Computer                131
# Money Management                   122
# Media                              104
# Energy                              87
# Non-consumer industrial             83
# Technology-Medical                  78
# Mining and metals                   68
# Constrution                         61
# Other                               59
# Hedge funds                         43
# Private equity/leveraged buyout     18
# 0                                    6
# Venture Capital                      5
# Name: industry, dtype: int64

# %% [markdown]
# How many self made billionaires vs. others?

# %%
rich2['selfmade'].value_counts()
# Out:
# self-made    1146
# inherited     505
# Name: selfmade, dtype: int64

# %% [markdown]
#  How old are billionaires? How old are billionaires self made vs. non self made? or different industries?

# %%
selfmade=rich2[rich2['selfmade']=='self-made']
nonselfmade=rich2[rich2['selfmade']=='inherited']
print("The values for self made billionaires")
selfmade['age'].value_counts()
selfmade['age'].hist()
# Out:
# The values for self made billionaires

# %%
print("The values for non-self made billionaires")
nonselfmade['age'].value_counts()
nonselfmade['age'].hist(label='Self Made Billionaires Age vs Number')
# Out:
# The values for non-self made billionaires

# %%
rich2['age'].value_counts()

# %% [markdown]
# Who are the youngest billionaires? The oldest?

# %%
rich2.sort_values(by='age').head(10)
# Out:
#         year                        name    rank    citizenship countrycode  \
# 1084  2014.0                 Perenna Kei  1284.0      Hong Kong         HKG
# 313   2014.0             Mark Zuckerberg    21.0  United States         USA
# 117   2014.0            Dustin Moskovitz   202.0  United States         USA
# 976   2014.0         Anton Kathrein, Jr.  1270.0        Germany         DEU
# 116   2014.0                Drew Houston  1372.0  United States         USA
# 970   2014.0  Albert von Thurn und Taxis  1092.0        Germany         DEU
# 423   2014.0                Scott Duncan   215.0  United States         USA
# 532   2014.0             Eduardo Saverin   367.0         Brazil         BRA
# 1382  2014.0                 Yang Huiyan   196.0          China         CHN
# 1496  2014.0                 Fahd Hariri  1372.0        Lebanon         LBN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1084                1.3  inherited            inherited  female  24.0
# 313                28.5  self-made  founder non-finance    male  29.0
# 117                 6.8  self-made  founder non-finance    male  29.0
# 976                 1.4  inherited            inherited    male  29.0
# 116                 1.2  self-made  founder non-finance    male  30.0
# 970                 1.6  inherited            inherited    male  30.0
# 423                 6.3  inherited            inherited    male  31.0
# 532                 4.1  self-made  founder non-finance    male  31.0
# 1382                6.9  inherited            inherited  female  32.0
# 1496                1.2  inherited            inherited    male  33.0
#
#                      ...                  \
# 1084                 ...
# 313                  ...
# 117                  ...
# 976                  ...
# 116                  ...
# 970                  ...
# 423                  ...
# 532                  ...
# 1382                 ...
# 1496                 ...
#
#                                                   notes  \
# 1084                              inherited from father
# 313                                                 NaN
# 117                                                 NaN
# 976                                      3rd generation
# 116                                                 NaN
# 970   monopoly on postal service in germany, nationa...
# 423                               inherited from father
# 532                                                 NaN
# 1382                              inherited from father
# 1496                              inherited from father
#
#                                                  notes2  \
# 1084                                                NaN
# 313                                                 NaN
# 117                                                 NaN
# 976                                                 NaN
# 116                                                 NaN
# 970   two older sisters, did not inherit title becau...
# 423                                                 NaN
# 532                                                 NaN
# 1382                                                NaN
# 1496                                                NaN
#
#                                                  source  \
# 1084           http://en.wikipedia.org/wiki/Perenna_Kei
# 313      http://www.forbes.com/profile/mark-zuckerberg/
# 117       http://en.wikipedia.org/wiki/Dustin_Moskovitz
# 976   http://www.forbes.com/profile/anton-kathrein-jr/#
# 116           http://en.wikipedia.org/wiki/Drew_Houston
# 970        http://en.wikipedia.org/wiki/Thurn_und_Taxis
# 423   http://en.wikipedia.org/wiki/Scott_Duncan_(bus...
# 532        http://en.wikipedia.org/wiki/Eduardo_Saverin
# 1382           http://en.wikipedia.org/wiki/Yang_Huiyan
# 1496          http://en.wikipedia.org/wiki/Rafik_Hariri
#
#                                                source_2  \
# 1084  http://www.loganestate.com/en/about.aspx?ftid=294
# 313                                                 NaN
# 117     http://www.forbes.com/profile/dustin-moskovitz/
# 976                                                 NaN
# 116      http://en.wikipedia.org/wiki/Dropbox_(service)
# 970   http://en.wikipedia.org/wiki/Albert,_12th_Prin...
# 423        http://www.forbes.com/profile/dannine-avara/
# 532   http://www.bloomberg.com/news/articles/2012-05...
# 1382                                                NaN
# 1496   http://en.wikipedia.org/wiki/Astra_International
#
#                                                source_3  source_4  \
# 1084                                                NaN       NaN
# 313                                                 NaN       NaN
# 117   https://www.facebook.com/facebook/info?tab=pag...       NaN
# 976                                                 NaN       NaN
# 116         http://www.forbes.com/profile/drew-houston/       NaN
# 970                                                 NaN       NaN
# 423                                                 NaN       NaN
# 532                                                 NaN       NaN
# 1382                                                NaN       NaN
# 1496  Hariri son takes up political reins in Lebanon...       NaN
#
#               Country Name    Year         Value  \
# 1084  Hong Kong SAR, China  2014.0  2.908964e+11
# 313          United States  2014.0  1.741900e+13
# 117          United States  2014.0  1.741900e+13
# 976                Germany  2014.0  3.852556e+12
# 116          United States  2014.0  1.741900e+13
# 970                Germany  2014.0  3.852556e+12
# 423          United States  2014.0  1.741900e+13
# 532                 Brazil  2014.0  2.346118e+12
# 1382                 China  2014.0  1.036011e+13
# 1496               Lebanon  2014.0  4.573095e+10
#
#      percentageofcountrygdptheirwealthis
# 1084                        4.468945e-12
# 313                         1.636144e-12
# 117                         3.903783e-13
# 976                         3.633951e-13
# 116                         6.889029e-14
# 970                         4.153087e-13
# 423                         3.616740e-13
# 532                         1.747568e-12
# 1382                        6.660164e-13
# 1496                        2.624044e-11
#
# [10 rows x 34 columns]

# %%
rich2.sort_values(by='age',ascending=False).head(10)
# Out:
#         year                    name    rank    citizenship countrycode  \
# 95    2014.0  David Rockefeller, Sr.   580.0  United States         USA
# 279   2014.0          Kirk Kerkorian   328.0  United States         USA
# 1612  2014.0           Karl Wlaschek   305.0        Austria         AUT
# 170   2014.0           Henry Hillman   687.0  United States         USA
# 994   2014.0      Erika Pohl-Stroher  1154.0        Germany         DEU
# 1017  2014.0           Karl Albrecht    23.0        Germany         DEU
# 509   2014.0       Sulaiman Al Rajhi   931.0   Saudi Arabia         SAU
# 19    2014.0       Anne Cox Chambers    58.0  United States         USA
# 495   2014.0   William Moncrief, Jr.  1565.0  United States         USA
# 840   2014.0            Marcel Adams  1465.0         Canada         CAN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 95                  2.9  inherited            inherited    male  98.0
# 279                 4.5  self-made    self-made finance    male  96.0
# 1612                4.8  self-made  founder non-finance    male  96.0
# 170                 2.5  inherited            inherited    male  95.0
# 994                 1.5  inherited            inherited  female  95.0
# 1017               25.0  self-made            executive    male  94.0
# 509                 1.9  self-made    self-made finance    male  94.0
# 19                 15.5  inherited            inherited  female  94.0
# 495                 1.0  inherited            inherited    male  93.0
# 840                 1.1  self-made    self-made finance    male  93.0
#
#                      ...                  \
# 95                   ...
# 279                  ...
# 1612                 ...
# 170                  ...
# 994                  ...
# 1017                 ...
# 509                  ...
# 19                   ...
# 495                  ...
# 840                  ...
#
#                                                   notes  \
# 95    family made most of fortune in the late 19th a...
# 279                                   purchased in 1969
# 1612                                                NaN
# 170                               inherited from father
# 994                                      3rd generation
# 1017  (split from Aldi Nord in 1966, but both branch...
# 509                                                 NaN
# 19                               inherited from brother
# 495             joined father's business following WWII
# 840                                                 NaN
#
#                                         notes2  \
# 95                                         NaN
# 279                                        NaN
# 1612                                       NaN
# 170                                        NaN
# 994                   23% stake in the company
# 1017  took over mother's single grocerty store
# 509                                        NaN
# 19                                         NaN
# 495                                        NaN
# 840                                        NaN
#
#                                                  source  \
# 95       http://en.wikipedia.org/wiki/David_Rockefeller
# 279         http://en.wikipedia.org/wiki/Kirk_Kerkorian
# 1612                 http://en.wikipedia.org/wiki/BILLA
# 170        http://www.forbes.com/profile/henry-hillman/
# 994   http://www.forbes.com/profile/erika-pohl-stroher/
# 1017         http://en.wikipedia.org/wiki/Karl_Albrecht
# 509          http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 19       http://en.wikipedia.org/wiki/Anne_Cox_Chambers
# 495       http://en.wikipedia.org/wiki/William_Moncrief
# 840         http://www.forbes.com/profile/marcel-adams/
#
#                                                source_2  \
# 95            http://en.wikipedia.org/wiki/Standard_Oil
# 279       http://www.forbes.com/profile/kirk-kerkorian/
# 1612         http://en.wikipedia.org/wiki/Karl_Wlaschek
# 170          http://en.wikipedia.org/wiki/Calgon_Carbon
# 994                  http://en.wikipedia.org/wiki/Wella
# 1017  http://www.bloomberg.com/news/articles/2014-07...
# 509   http://www.alrajhibank.com.sa/ar/investor-rela...
# 19    http://www.forbes.com/lists/2010/10/billionair...
# 495              http://www.moncriefoil.com/history.htm
# 840   http://business.financialpost.com/news/93-year...
#
#                                                source_3  source_4  \
# 95      http://en.wikipedia.org/wiki/Rockefeller_family       NaN
# 279   PROFILE: Las Vegas billionaire amassed his wea...       NaN
# 1612  https://www.billa.at/Footer_Nav_Seiten/Geschic...       NaN
# 170                                                 NaN       NaN
# 994                                                 NaN       NaN
# 1017        http://aldiuscareers.com/about-aldi/history       NaN
# 509   http://www.alrajhibank.com.sa/ar/about-us/page...       NaN
# 19    http://www.nytimes.com/2007/05/30/business/med...       NaN
# 495                                                 NaN       NaN
# 840                                                 NaN       NaN
#
#        Country Name    Year         Value percentageofcountrygdptheirwealthis
# 95    United States  2014.0  1.741900e+13                        1.664849e-13
# 279   United States  2014.0  1.741900e+13                        2.583386e-13
# 1612        Austria  2014.0  4.363436e+11                        1.100050e-11
# 170   United States  2014.0  1.741900e+13                        1.435214e-13
# 994         Germany  2014.0  3.852556e+12                        3.893519e-13
# 1017        Germany  2014.0  3.852556e+12                        6.489198e-12
# 509    Saudi Arabia  2014.0  7.462485e+11                        2.546069e-12
# 19    United States  2014.0  1.741900e+13                        8.898329e-13
# 495   United States  2014.0  1.741900e+13                        5.740858e-14
# 840          Canada  2014.0  1.786655e+12                        6.156756e-13
#
# [10 rows x 34 columns]

# %% [markdown]
# Maybe plot their net worth vs age (scatterplot)

# %%
rich2.plot(kind='scatter',x='age',y='networthusbillion')
